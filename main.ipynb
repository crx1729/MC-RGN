# %%
import argparse
from train import *

# %%
parser = argparse.ArgumentParser()
parser.add_argument('--dataset', default='Movie', type=str)
parser.add_argument('--batch_size', default=256, type=int)
parser.add_argument('--graph_layer', default=1, type=int)
parser.add_argument('--lr', default=0.001, type=float)
parser.add_argument('--maxlen', default=50, type=int)
parser.add_argument('--loss', default='BCE', type=str)
parser.add_argument('--MarkovWeight', default=1.0, type=float)
parser.add_argument('--hidden_units', default=64, type=int)
parser.add_argument('--num_blocks', default=2, type=int)
parser.add_argument('--k', default=10, type=int)
parser.add_argument('--num_epochs', default=100, type=int)
parser.add_argument('--num_heads', default=1, type=int)
parser.add_argument('--dropout_rate', default=0.3, type=float)
parser.add_argument('--l2_emb', default=0.0, type=float)
parser.add_argument('--device', default='cuda', type=str)
parser.add_argument('--inference_only', default=False, type=str)
args = parser.parse_args([])

# %%
data_file = './dataset'
train(data_file, args)
# Out:
# average sequence length: 163.50
# MCMat got!
# loss in epoch 1 iteration 0: 3.894846295773382
# loss in epoch 2 iteration 0: 1.2738309809024406
# loss in epoch 3 iteration 0: 7.695186686810824
# loss in epoch 4 iteration 0: 585.6152590541013
# loss in epoch 5 iteration 0: 32.84572372187781
# loss in epoch 6 iteration 0: 2.205329806688636
# loss in epoch 7 iteration 0: 0.7788251692452193
# loss in epoch 8 iteration 0: 2.5340845615475676
# loss in epoch 9 iteration 0: 9.84665162943463
# loss in epoch 10 iteration 0: 1.0508518559568514
# loss in epoch 11 iteration 0: 51.667229353153786
# loss in epoch 12 iteration 0: 7.790087868595181
# loss in epoch 13 iteration 0: 0.9215850323265034
# loss in epoch 14 iteration 0: 1.202051110823382
# loss in epoch 15 iteration 0: 0.8000580946564437
# loss in epoch 16 iteration 0: 0.7687756817385606
# loss in epoch 17 iteration 0: 1.9259949014810427
# loss in epoch 18 iteration 0: 1.1961071363042253
# loss in epoch 19 iteration 0: 1.1271608163467575
# ...
